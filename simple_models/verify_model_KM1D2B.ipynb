# %% [markdown]
# This notebook intends to verify the implementation of the model `KM1D2B` by comparing the dimensionless time-radius curves at various parameters.
#
# From the paper `A.A. Doinikov, TTranslational motion of two interacting bubbles in a strong acoustic field, Phys. Rev. E, 64, (2001), p. 026301`, multiple figures are recalculated to verify the present implementation.

# %%
import matplotlib.pyplot as plt
from single_solution_KM1D2B import DualBubble as KMBubbles
from single_solution_KM1D2B import P0, CL

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.size"  : 16,
    "font.serif" : "Palatino"})

# %%
LR = CL / (20 * 1000)       # Reference Wave-Length

# %%
# Figure 2 (a)
R0 = [7, 5]
PA = [1.2 * P0 * 1e-5]
km = KMBubbles(R0, [20], PA, k=1, AC_FIELD="CONST")
km.x0[1] = 200 *1e-6 / LR
km.T = 100

t, _, _, x, _ = km.integrate()

plt.figure(figsize=(10, 6))
plt.plot(t, x[0] * LR * 1e6, "r-", label="Bubble-1")
plt.plot(t, x[1] * LR * 1e6, "b-", label="Bubble-2")
plt.xlabel(r'$\tau$')
plt.ylabel(r'$z\, \mu m$')
plt.legend()
plt.grid('both')
plt.show()

# %%
# Figure 2 (b)
R0 = [6, 4]
PA = [1.21 * P0 * 1e-5]
km = KMBubbles(R0, [20], PA, k=1, AC_FIELD="CONST")
km.x0[1] = 200 *1e-6 / LR
km.T = 50

t, _, _, x, _ = km.integrate()

plt.figure(figsize=(10, 6))
plt.plot(t, x[0] * LR * 1e6, "r-", label="Bubble-1")
plt.plot(t, x[1] * LR * 1e6, "b-", label="Bubble-2")
plt.xlabel(r'$\tau$')
plt.ylabel(r'$z\, \mu m$')
plt.legend()
plt.grid('both')
plt.show()

# %%
# Figure 2 (c)
R0 = [3, 5]
PA = [1.22 * P0 * 1e-5]
km = KMBubbles(R0, [20], PA, k=1, AC_FIELD="CONST")
km.x0[1] = 200 *1e-6 / LR
km.T = 100

t, _, _, x, _ = km.integrate()

plt.figure(figsize=(10, 6))
plt.plot(t, x[0] * LR * 1e6, "r-", label="Bubble-1")
plt.plot(t, x[1] * LR * 1e6, "b-", label="Bubble-2")
plt.xlabel(r'$\tau$')
plt.ylabel(r'$z\, \mu m$')
plt.legend()
plt.grid('both')
plt.show()

# %%
# Figure 2 (d)
R0 = [5, 4]
PA = [1.20 * P0 * 1e-5]
km = KMBubbles(R0, [20], PA, k=1, AC_FIELD="CONST")
km.x0[1] = 200 *1e-6 / LR
km.T = 100

t, _, _, x, _ = km.integrate()

plt.figure(figsize=(10, 6))
plt.plot(t, x[0] * LR * 1e6, "r-", label="Bubble-1")
plt.plot(t, x[1] * LR * 1e6, "b-", label="Bubble-2")
plt.xlabel(r'$\tau$')
plt.ylabel(r'$z\, \mu m$')
plt.legend()
plt.grid('both')
plt.show()

# %%
# Figure 2 (e)
R0 = [4, 3]
PA = [1.21 * P0 * 1e-5]
km = KMBubbles(R0, [20], PA, k=1, AC_FIELD="CONST")
km.x0[1] = 200 *1e-6 / LR
km.T = 100

t, _, _, x, _ = km.integrate()

plt.figure(figsize=(10, 6))
plt.plot(t, x[0] * LR * 1e6, "r-", label="Bubble-1")
plt.plot(t, x[1] * LR * 1e6, "b-", label="Bubble-2")
plt.xlabel(r'$\tau$')
plt.ylabel(r'$z\, \mu m$')
plt.legend()
plt.grid('both')
plt.show()

# %%
# Figure 2 (f)
R0 = [3, 2]
PA = [1.3 * P0 * 1e-5]
km = KMBubbles(R0, [20], PA, k=1, AC_FIELD="CONST")
km.x0[1] = 150 *1e-6 / LR
km.T = 100

t, _, _, x, _ = km.integrate()

plt.figure(figsize=(10, 6))
plt.plot(t, x[0] * LR * 1e6, "r-", label="Bubble-1")
plt.plot(t, x[1] * LR * 1e6, "b-", label="Bubble-2")
plt.xlabel(r'$\tau$')
plt.ylabel(r'$z\, \mu m$')
plt.legend()
plt.grid('both')
plt.show()

# %%
# Figure 3 (a)
R0 = [7, 5]
PA = [-1.2 * P0 * 1e-5]
km = KMBubbles(R0, [20], PA, k=1, AC_FIELD="CONST")
km.x0[1] = 200 *1e-6 / LR
km.T = 10

t, _, _, x, _ = km.integrate()

plt.figure(figsize=(10, 6))
plt.plot(t, x[0] * LR * 1e6, "r-", label="Bubble-1")
plt.plot(t, x[1] * LR * 1e6, "b-", label="Bubble-2")
plt.xlabel(r'$\tau$')
plt.ylabel(r'$z\, \mu m$')
plt.legend()
plt.grid('both')
plt.show()

# %%
# Figure 3 (b)
R0 = [5, 4]
PA = [-1.2 * P0 * 1e-5]
km = KMBubbles(R0, [20], PA, k=1, AC_FIELD="CONST")
km.x0[1] = 200 *1e-6 / LR
km.T = 10

t, _, _, x, _ = km.integrate()

plt.figure(figsize=(10, 6))
plt.plot(t, x[0] * LR * 1e6, "r-", label="Bubble-1")
plt.plot(t, x[1] * LR * 1e6, "b-", label="Bubble-2")
plt.xlabel(r'$\tau$')
plt.ylabel(r'$z\, \mu m$')
plt.legend()
plt.grid('both')
plt.show()

# %%
# Figure 4 (a)
R0 = [6, 5]
PA = [-1.2 * P0 * 1e-5]
km = KMBubbles(R0, [20], PA, k=1, AC_FIELD="CONST")
km.x0[1] = 300 *1e-6 / LR
km.T = 7.51

t, r, _, x, _ = km.integrate()

plt.figure(figsize=(10, 6))
plt.plot(t, (x[1]-x[0]) * LR * 1e6, "r-", label="D(t)")
plt.plot(t, (r[0]*R0[0] + r[1]*R0[1]), "b-", label="$R_0(t)+R_1(t)$")
plt.xlabel(r'$\tau$')
plt.ylabel(r'$z\, \mu m$')
plt.legend()
plt.grid('both')
plt.show()

# %%
# Figure 4 (b)
R0 = [6, 4]
PA = [-1.21 * P0 * 1e-5]
km = KMBubbles(R0, [20], PA, k=1, AC_FIELD="CONST")
km.x0[1] = 200 *1e-6 / LR
km.T = 10

t, r, _, x, _ = km.integrate()

plt.figure(figsize=(10, 6))
plt.plot(t, (x[1]-x[0]) * LR * 1e6, "r-", label="D(t)")
plt.plot(t, (r[0]*R0[0] + r[1]*R0[1]), "b-", label="$R_0(t)+R_1(t)$")
plt.xlabel(r'$\tau$')
plt.ylabel(r'$z\, \mu m$')
plt.legend()
plt.grid('both')
plt.show()
